# %%
#!pip install pandas numpy word2number collections
from word2number import w2n
import pandas as pd
import numpy as np
import unicodedata
from collections import Counter
import matplotlib.pyplot as plt
import string

# %% [markdown]
# ## **Estructura a seguir**
# 1. ***Limpieza de datos***
#    - Eliminar duplicador
#    - Tratar los valores nulos
#    - Estandarizar el formato
# 3. ***aplicar el analisis***
#    - Resumen estadistico
#        - Media
#        - Moda
#        - Distribucion de ratings

# %%
datos = pd.read_csv('resenas_flowapp.csv', sep=',')

# %%
df = (
    datos
    .copy()
        .drop_duplicates()
     )
df['fecha'] = pd.to_datetime(df['fecha'])

# %% [markdown]
# ## **Limpieza de datos**
# Principalmente se limpio el formato del texto para quitar los emojis, y texto caracteristico (tildes)

# %%
# normalizar texto, estoy usando string para quitar los signos de puntuacion y que quede liso el texto
def limpiar_texto(texto):
    if isinstance(texto, str):
        # Eliminar tildes y emojis
        texto = (
            unicodedata.normalize("NFKD", texto)
            .encode("ascii", "ignore")
            .decode("utf-8")
        )
        return texto.translate(str.maketrans('', '', string.punctuation))
    return texto.translate(str.maketrans('', '', string.punctuation))

#limpiar el rating

def limpiar_rating(valor):
    
    # convertir los valores anormales o nules que se toman como texto a NaN tratable 
    if pd.isna(valor) or str(valor).strip() in ["", "?", "nan", "None"]:
        return np.nan

    # convertir a string y quitar los espacios
    val_str = str(valor).strip().lower()

    # detectar si es un numero
    try:
        # si es un numero ya permitido transformarlo a flotante
        numero = float(val_str)
        
    except ValueError:
        # transformar de texto a numero directo
        try:
            numero = float(w2n.word_to_num(val_str))
        except ValueError:
            # Si no se puede convertir, pasarlo a entero
            return np.nan

       # para tratar valores que estan fuera del rango o con valores diferentes
    if numero < 0:
        return 0
    elif numero > 5:
        return 5
    else:
        return numero

# %% [markdown]
# ## **Scripts para detectar y mostrar**

# %%
def palabras_frecuentes_por_rating(df, top_n=4):
    # print("--- PALABRAS MÁS FRECUENTES POR RATING ---")
    
    # eliminando los posibles articulos, y palabras "sin valor" para el analisis
    stop_words = {'fue','con','fu','fa,','y', 'el', 'la', 'de', 'que', 'un', 'una', 'muy', 'pero', 'no', 'me', 'sin', 'ni', 'a', 'las',',','en','los', 'es'}

    rating_palabras = {}
    numero={}
    for rating, grupo in df.groupby('rating'):
        
        # uniendo todas las palabras en un array
        todas_las_palabras = " ".join(grupo['texto']).split()
        
        # realizar la busqueda de las palabras sin tener en cuenta las soptwords
        palabras_filtradas = [p for p in todas_las_palabras if p not in stop_words]
        
        # con que frecuencia se repite
        conteo = Counter(palabras_filtradas)
        
        rating_palabras[rating] = conteo.most_common(top_n) # palabras comunes
        
        numero[rating] = conteo.total() # total de palabras
        
    return rating_palabras,numero

def resumen_rating(df, dict_top_palabras,n_palabras):
    NEGRILA = "\033[1m"
    RESET = "\033[0m"
    
    titulo_principal = "Resumen Estadístico Y Distribución De Ratings"
    
    # Métricas estadísticas básicas
    media_rating = df['rating'].mean()
    mediana_rating = df['rating'].median()
    total_resenas = len(df)
    
    print("\n" + "-" * 65)
    print(titulo_principal.center(65))
    print("-" * 65)
    
    #cuadro de media y mediana
    cuadro_media = f"Media de rating    \n{media_rating:.2f}          "
    cuadro_mediana = f"Mediana de rating \n{mediana_rating:.1f}            "
    print(cuadro_media)
    print(cuadro_mediana)
    # aqui empiezan las frecuencias (la grafica se muestra en terminal)
    
    print("--- Frecuencias Y Distribución De Ratings ---")
    
    conteo_ratings = df['rating'].value_counts().sort_index()
    max_frecuencia = conteo_ratings.max() if not conteo_ratings.empty else 1
    max_ancho_barra = 25
    
    # bucle de grafica
    for rating in sorted(df['rating'].unique()):
        frecuencia = conteo_ratings.get(rating, 0)
        longitud_barra = int((frecuencia / max_frecuencia) * max_ancho_barra)
        barra = "█" * longitud_barra
        pct = (frecuencia / total_resenas) * 100
        print(f" Rating {rating}  | {barra:<25} {frecuencia:>4} ({pct:>5.1f}%)")
        
    print("\n" + "-" * 65)
    
    # tabla de detalle por rating
    print("\n--- Resumen Detallado Por Rating ---")
    datos_tabla = []
    for rating in sorted(df['rating'].unique()):
        cantidad = conteo_ratings.get(rating, 0)
        pct = f"{(cantidad / total_resenas) * 100:.1f}%"

        datos_tabla.append({
            'Rating': f"{rating} ",
            'Reseñas': cantidad,
            '% Total': pct
        })
        
    df_resumen = pd.DataFrame(datos_tabla)
    
    # Formateamos los nombres de las columnas en Capital Letter
    df_resumen.columns = [col.title() for col in df_resumen.columns]
        
    print(df_resumen.to_string(index=False))
    print("-" * 65 + "\n")

    #script de las palabras mas frecuentes
    print("\n" + "=" * 65)
    print("    Palabras mas frecuentes")
    print("=" * 65)

    for rating, lista_tuplas in diccionario_ratings.items():
        total_p = n_palabras.get(rating, 1)  # Obtiene el total de palabras de ese rating
        palabras_formateadas = []
    # guardo las palabras en un solo formato de diccionario
        lista_palabras = []
        for palabra, frec_abs in lista_tuplas:
            pct = (frec_abs / total_p) * 100
            palabras_formateadas.append(f"{palabra} {frec_abs} ({pct:.2f}%)")
        
    # Aqui se unen las palabras que estan en 
        cadena_palabras = " - ".join(palabras_formateadas)
    
    # Aqui se imprimen las palabras de cada rating
        print(f"\nRating {int(rating)}  (Total palabras: {total_p})")
        print(f"\n")
        print(f" {NEGRILA}Palabras mas repetidas {RESET}: \n {cadena_palabras}")

    print("\n" + "=" * 65 + "\n")

# %%
# usar la funcion y convertirlo a minuscula
df["texto"] = (
    df["texto"].apply(limpiar_texto).str.lower().str.strip()
              )

# cambiando el texto nulo por un valor estandar
df['texto'] = df['texto'].fillna('sin comentarios')

# usando la funcion para limpiar los ratings
df['rating'] = df['rating'].apply(limpiar_rating)

# quitando los valores nulos para no suponer ni sesgar la informacion
df = df.dropna(subset=['rating'])

# %%
diccionario_ratings,n_palabras = palabras_frecuentes_por_rating(df,top_n=4)

# %%
resumen_rating(
    df, diccionario_ratings, n_palabras
)
# Out:
# -----------------------------------------------------------------
#           Resumen Estadístico Y Distribución De Ratings
# -----------------------------------------------------------------
# Media de rating
# 3.85
# Mediana de rating
# 4.0
# --- Frecuencias Y Distribución De Ratings ---
#  Rating 0.0  |                              3 (  0.5%)
#  Rating 1.0  | ███                         34 (  6.0%)
#  Rating 2.0  | ██████                      53 (  9.3%)
#  Rating 3.0  | █████████                   81 ( 14.3%)
#  Rating 4.0  | ████████████████████       180 ( 31.7%)
#  Rating 5.0  | █████████████████████████  217 ( 38.2%)
#
# -----------------------------------------------------------------
#
# --- Resumen Detallado Por Rating ---
# Rating  Reseñas % Total
#   0.0         3    0.5%
#   1.0        34    6.0%
#   2.0        53    9.3%
#   3.0        81   14.3%
#   4.0       180   31.7%
#   5.0       217   38.2%
# -----------------------------------------------------------------
#
#
# ...
